# %% [markdown]
# <a href="https://colab.research.google.com/github/georgeliu1998/tf_and_colab/blob/master/tf_and_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.12.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: astor, tensorboard, six, gast, absl-py, keras-applications, keras-preprocessing, wheel, protobuf, termcolor, grpcio, numpy
# Required-by: stable-baselines, magenta, fancyimpute

# %%
a = tf.constant(1, name='a_var')          
b = tf.constant(2, name='b_bar')              

c = tf.Variable(a + b)  

init = tf.global_variables_initializer()         
                                                 
with tf.Session() as session:                    
    session.run(init)                            
    print(session.run(c))
# Out:
# 3

# %%
a
# Out:
# <tf.Tensor 'a_var_3:0' shape=() dtype=int32>

# %%
c
# Out:
# <tf.Variable 'Variable_4:0' shape=() dtype=int32_ref>

# %%
var = tf.Variable(2) 
print(var)

init = tf.global_variables_initializer()  
with tf.Session() as sess:
  sess.run(init)
  var = sess.run(var)
  print(var)
# Out:
# <tf.Variable 'Variable_5:0' shape=() dtype=int32_ref>
# 2

# %%
a = tf.constant(1, dtype=tf.float32)
b = tf.constant(-20, dtype=tf.float32)
c = tf.constant(-100, dtype=tf.float32)

# %%
x = tf.placeholder(dtype=tf.float32)

# %%
y_parabola = a * (x ** 2) + b * x + c

# %%
x_feed = np.linspace(-10, 30, num=1000)

# %%
with tf.Session() as sess:
  results = sess.run(y_parabola, feed_dict={x: x_feed})

# %%
print(results)

# %%
x = tf.constant([[1], [2], [3], [4]], dtype=tf.float32)
y_true = tf.constant([[0], [-1], [-2], [-3]], dtype=tf.float32)

linear_model = tf.layers.Dense(units=1, bias_initializer=tf.constant_initializer(1))

y_pred = linear_model(x)
loss = tf.losses.mean_squared_error(labels=y_true, predictions=y_pred)

optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)
for i in range(1000):
  _, loss_value = sess.run((train, loss))
  #print(loss_value)

print('Weight is: ', sess.run(linear_model.weights))
print('Bias is: ', sess.run(linear_model.bias))


print(sess.run(y_pred))
# Out:
# Weight is:  [array([[-0.989387]], dtype=float32), array([0.9687963], dtype=float32)]
# Bias is:  [0.9687963]
# [[-0.02059066]
#  [-1.0099776 ]
#  [-1.9993646 ]
#  [-2.9887516 ]]

# %%
y2 = -0.989387 * x2 + 0.9687963
x2 = np.array([1, 2, 3, 4])
y2
# Out:
# array([-0.0205907, -1.0099777, -1.9993647, -2.9887517])

# %%
linear_model.variables
# Out:
# [<tf.Variable 'dense_11/kernel:0' shape=(1, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_11/bias:0' shape=(1,) dtype=float32_ref>]

# %%
linear_model.bias
# Out:
# <tf.Variable 'dense_11/bias:0' shape=(1,) dtype=float32_ref>

# %%
linear_model.weights
# Out:
# [<tf.Variable 'dense_11/kernel:0' shape=(1, 1) dtype=float32_ref>,
#  <tf.Variable 'dense_11/bias:0' shape=(1,) dtype=float32_ref>]

# %%
linear_model.get_weights()
# Out:
# [array([[-0.21042848]], dtype=float32), array([1.], dtype=float32)]

# %%
linear_model.get_config()
# Out:
# {'activation': 'linear',
#  'activity_regularizer': None,
#  'bias_constraint': None,
#  'bias_initializer': {'class_name': 'Constant',
#   'config': {'dtype': 'float32', 'value': 1}},
#  'bias_regularizer': None,
#  'dtype': 'float32',
#  'kernel_constraint': None,
#  'kernel_initializer': None,
#  'kernel_regularizer': None,
#  'name': 'dense_14',
#  'trainable': True,
#  'units': 1,
#  'use_bias': True}

# %%
#*********************************************#
x = tf.constant([[1], [2], [3], [4]], dtype=tf.float32)
y_true = tf.constant([[0], [-1], [-2], [-3]], dtype=tf.float32)

linear_model = tf.layers.Dense(units=1)

y_pred = linear_model(x)
loss = tf.losses.mean_squared_error(labels=y_true, predictions=y_pred)

optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)
for i in range(100000):
  _, loss_value = sess.run((train, loss))
  print(loss_value)

print(sess.run(y_pred))
# Out:
# 8.662651
# 6.033565
# 4.2091637
# 2.9431148
# 2.0644946
# 1.4547062
# 1.0314536
# 0.7376361
# 0.53363085
# 0.39194566
# 0.2935038
# 0.22506817
# 0.17745417
# 0.14428852
# 0.12114921
# 0.10496751
# 0.09361441
# 0.085612506
# 0.079936646
# 0.07587552
# 0.07293559
# 0.07077432
# 0.06915407
# 0.06791001
# 0.06692763
# 0.06612755
# 0.065454684
# 0.064870805
# 0.06434934
# 0.06387191
# 0.06342569
# 0.06300184
# 0.06259419
# 0.062198468
# 0.06181167
# 0.061431773
# 0.061057307
# 0.060687285
# 0.060320966
# 0.059957925
# 0.059597798
# 0.0592403
# 0.058885314
# 0.0585327
# 0.05818235
# 0.057834215
# 0.057488248
# 0.05714442
# 0.056802653
# 0.05646298
# 0.056125343
# 0.05578975
# 0.055456195
# 0.055124618
# 0.054795
# 0.054467387
# 0.054141734
# 0.05381803
# 0.053496253
# 0.053176407
# 0.052858487
# 0.052542433
# 0.0522283
# 0.051916037
# 0.051605627
# 0.051297087
# 0.050990377
# 0.050685525
# 0.050382487
# 0.050081253
# 0.04978183
# 0.049484197
# 0.049188323
# 0.04889425
# 0.048601903
# ...
